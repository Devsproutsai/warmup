# %%
#output from warmup question validation

candidate_skills = [
  {
    "criteria": "Web Development & Programming Skills",
    "skills": [
      {
        "skills": "Java",
        "reason": "The candidate mentioned that they possess Java skills in the Web Development & Programming Skills domain."
      }
    ]
  },
  {
    "criteria": "Advanced Infrastructure and Distributed Systems Development",
    "skills": [
      
      {
        "skills": "Protobuf",
        "reason": "The candidate mentioned that they possess this skill."
      },
      {
        "skills": "Docker",
        "reason": "The candidate mentioned that they possess this skill."
      },
      {
        "skills": "Kubernetes",
        "reason": "The candidate mentioned that they possess this skill."
      }
    ]
  },
  {
    "criteria": "Computer Science, Programming and Automation Skills",
    "skills": [
      {
        "skills": "UNIX/Linux",
        "reason": "The candidate mentioned that they possess UNIX/Linux skills in the Computer Science, Programming and Automation Skills domain."
      }
    ]
  },
  {
    "criteria": "Cloud Computing and Platform Services",
    "skills": [
      {
        "skills": "AWS",
        "reason": "The candidate mentioned that they possess AWS skills in the Cloud Computing and Platform Services domain."
      }
    ]
  },
  {
    "criteria": "Big Data and Cloud-Based Storage Technologies",
    "skills": [
    
      {
        "skills": "kafka",
        "reason": "The candidate mentioned that they possess expertise in kafka."
      }
    ]
  },
  {
    "criteria": "Network and Security Management Skills",
    "skills": [
      {
        "skills": "OAuth2",
        "reason": "The candidate mentioned that they possess OAuth2 skills in the Network and Security Management Skills domain."
      }
    ]
  },
  {
    "criteria": "Advanced Taxation and Confidential Data Management Skills",
    "skills": [
      {
        "skills": "Cryptography",
        "reason": "The candidate has mentioned that they possess Cryptography skills in the Advanced Taxation and Confidential Data Management Skills domain."
      }
    ]
  },
  {
    "criteria": "AI, Machine Learning and Deep Learning Skills",
    "skills": [
      {
        "skills": "machine learning",
        "reason": "The candidate mentioned that they possess machine learning skills"
      },
      {
        "skills": "Deep Neural Networks",
        "reason": "The candidate mentioned that they have expertise in Deep Neural Networks"
      }
    ]
  },
  {
    "criteria": "Personal Development Skills",
    "skills": [
     
      {
        "skills": "Self-Starter",
        "reason": "The candidate mentioned that they possess this skill."
      }
    ]
  },
  {
    "criteria": "Communication, Ethics, and Team Collaboration",
    "skills": [
      {
        "skills": "Interpersonal Communication",
        "reason": "The candidate has mentioned that they possess Interpersonal Communication skills"
      }
    ]
  }
]

#list of must have skills
must_have_skills = ["Interpersonal Communication", "Java", "Designing Distributed Systems" ,"Kubernetes", "UNIX/Linux", "kafka"]

# %%
#collecting  known skill of the candidate

known_skills_to_candidate = []
for i in candidate_skills:
    for j in i['skills']:
        known_skills_to_candidate.append(j['skills'])
print(known_skills_to_candidate)
# Out:
# ['Java', 'Protobuf', 'Docker', 'Kubernetes', 'UNIX/Linux', 'AWS', 'kafka', 'OAuth2', 'Cryptography', 'machine learning', 'Deep Neural Networks', 'Self-Starter', 'Interpersonal Communication']

# %%
job_parser = {
    "question_selection_data": {
      "criterias": [
        {
          "skill": "Java",
          "criteria": "Web Development & Programming Skills",
          "description": "Java is a high-level, object-oriented programming language that is designed to have as few implementation dependencies as possible. It is a general-purpose programming language intended to let application developers write once, run anywhere (WORA), meaning that compiled Java code can run on all platforms that support Java without the need for recompilation.",
          "skimilar_skills": {
            "Java": 0.7378718136324849
          }
        },
        {
          "skill": "Designing Distributed Systems",
          "criteria": "Advanced Infrastructure and Distributed Systems Development",
          "description": "Designing Distributed Systems involves the creation and management of multiple small systems that communicate and coordinate to perform a task. These systems are spread across different networks, and can be located globally. The design process takes into account factors such as network latency, data consistency, and fault tolerance.",
          "skimilar_skills": {
            "Design Coordination": 0.6379338326925692
          }
        },
        {
          "skill": "gRPC",
          "criteria": "Advanced Infrastructure and Distributed Systems Development",
          "description": "gRPC is a high-performance, open-source universal remote procedure call (RPC) framework. It allows a client application to directly call methods on a server application on a different machine as if it was a local object, making it easier for you to create distributed applications and services.",
          "skimilar_skills": {
            "GCP": 0.5367286554931886
          }
        },
        {
          "skill": "Protobuf",
          "criteria": "Advanced Infrastructure and Distributed Systems Development",
          "description": "Protobuf, or Protocol Buffers, is a binary protocol developed by Google. It is a highly efficient and compact format that serializes structured data, used in both internal applications and in APIs. It's language-neutral, platform-neutral, extensible mechanism for serializing structured data.",
          "skimilar_skills": {
            "dataproc": 0.576257442338379
          }
        },
        {
          "skill": "Docker",
          "criteria": "Advanced Infrastructure and Distributed Systems Development",
          "description": "Docker is an open-source platform that automates the deployment, scaling, and management of applications. It uses containerization technology to bundle an application and its dependencies into a single object. This allows the application to be run reliably in different computing environments.",
          "skimilar_skills": {
            "Docker": 0.7683780786869202
          }
        },
        {
          "skill": "Kubernetes",
          "criteria": "Advanced Infrastructure and Distributed Systems Development",
          "description": "Kubernetes is an open-source platform designed to automate deploying, scaling, and operating application containers. It groups containers that make up an application into logical units for easy management and discovery.",
          "skimilar_skills": {
            "Hibernate": 0.6065841313238577
          }
        },
        {
          "skill": "UNIX/Linux",
          "criteria": "Computer Science, Programming and Automation Skills",
          "description": "Linux is a family of open-source Unix-like operating systems based on the Linux kernel. It's known for its robustness, flexibility, and security features. Linux is used in various systems such as servers, desktops, smartphones, routers, and gaming consoles.",
          "skimilar_skills": {
            "UNIX/Linux": 0.8243968900320036
          }
        },
        {
          "skill": "AWS",
          "criteria": "Cloud Computing and Platform Services",
          "description": "AWS, or Amazon Web Services, is a comprehensive, evolving cloud computing platform provided by Amazon. It provides a mix of infrastructure as a service (IaaS), platform as a service (PaaS) and packaged software as a service (SaaS) offerings. AWS services can offer an organization tools such as compute power, database storage and content delivery services.",
          "skimilar_skills": {
            "AWS Security Stack": 0.7380173674754926
          }
        },
        {
          "skill": "Lucene",
          "criteria": "Big Data and Cloud-Based Storage Technologies",
          "description": "Lucene is a high-performance, full-featured text search engine library written entirely in Java. It is a technology suitable for nearly any application that requires full-text search, especially cross-platform. Lucene comes with powerful, flexible, and highly efficient functionalities to perform searching and indexing across many websites, books, and documents.",
          "skimilar_skills": {
            "HTML": 0.5632171170300169
          }
        },
        {
          "skill": "kafka",
          "criteria": "Big Data and Cloud-Based Storage Technologies",
          "description": "Kafka is a distributed event streaming platform used by thousands of companies for high-performance data pipelines, streaming analytics, data integration, and mission-critical applications. It is designed to handle data streams from multiple sources and deliver them to multiple consumers. Kafka is highly valuable for enterprise infrastructures to process streaming data.",
          "skimilar_skills": {
            "kafka": 0.8783885214103455
          }
        },
        {
          "skill": "OAuth2",
          "criteria": "Network and Security Management Skills",
          "description": "OAuth2 is an authorization framework that enables applications to obtain limited access to user accounts on an HTTP service. It works by delegating user authentication to the service that hosts the user account and authorizing third-party applications to access the user account. OAuth2 provides a process for end-users to authorize third-party access to their server resources without sharing their credentials.",
          "skimilar_skills": {
            "AWS Security Stack": 0.4884492753055951
          }
        },
        {
          "skill": "Cryptography",
          "criteria": "Advanced Taxation and Confidential Data Management Skills",
          "description": "Cryptography involves creating written or generated codes that allow information to be kept secret. In digital security, cryptography provides the basis for several tools and techniques used to secure data and information systems. It includes techniques such as encryption (converting readable data into unreadable data to prevent unauthorized access) and decryption (converting the unreadable data back to its original form).",
          "skimilar_skills": {
            "Security": 0.6040771828041439
          }
        },
        {
          "skill": "machine learning",
          "criteria": "AI, Machine Learning and Deep Learning Skills",
          "description": "Machine Learning is a subset of artificial intelligence that involves the creation and use of algorithms that allow machines to learn from and make decisions based on data. It involves the development of self-learning algorithms to gain knowledge from that data, without being specifically programmed to do so. This can lead to new insights, predictions, and decision-making capabilities.",
          "skimilar_skills": {
            "machine learning": 0.8701548571295096
          }
        },
        {
          "skill": "Deep Neural Networks",
          "criteria": "AI, Machine Learning and Deep Learning Skills",
          "description": "Deep Neural Networks are artificial neural networks with multiple layers between the input and output layers. These intermediate layers, also known as hidden layers, are where the complex processing happens via systems of weighted 'neurons'. They are designed to model the way the human brain works, and have been successful in many AI tasks, especially those involving image and speech recognition.",
          "skimilar_skills": {
            "Generative Advarsarial Networks": 0.6992237958480235
          }
        },
        {
          "skill": "Problem Solving",
          "criteria": "Personal Development Skills",
          "description": "Problem Solving is a critical skill that involves identifying, analyzing, and solving problems of a complex nature. In a software engineering context, this often involves debugging code, troubleshooting system issues, or devising solutions to new challenges. It requires a logical and methodical approach, creativity, and the ability to work well under pressure.",
          "skimilar_skills": {
            "Problem Solving": 0.8029756962478348
          }
        },
        {
          "skill": "Self-Starter",
          "criteria": "Personal Development Skills",
          "description": "Being a Self-Starter is about taking the initiative, identifying opportunities and pursuing them without being told to do so. In the context of a software engineer, it could involve proactively identifying a problem in the code, creating a new functionality, or seeking to improve existing systems. It requires a high degree of motivation, resourcefulness, and the ability to work independently.",
          "skimilar_skills": {
            "Motivation": 0.5787787022187278
          }
        },
        {
          "skill": "Interpersonal Communication",
          "criteria": "Communication, Ethics, and Team Collaboration",
          "description": "Interpersonal communication is a soft skill that encompasses how well an individual communicates with others. This skill is central to any role as it dictates how effectively one can relay information, listen to others, form arguments, and engage in discussions or negotiations. It involves both verbal and non-verbal communication skills. Verbal skills include aspects such as clarity of speech, understanding the needs of the audience, and the ability to negotiate. Non-verbal communication, on the other hand, involves understanding and interpreting body language, eye contact, gestures, and the like. This skill is particularly important for a software engineer as they often work in teams and need to communicate effectively with their peers, managers, and sometimes clients. Mastery of interpersonal communication can lead to better team collaboration, higher efficiency, and improved problem-solving.",
          "skimilar_skills": {
            "Interpersonal Communication": 0.8376481423086505
          }
        }
      ],
      "description": "No description",
      "position": "Software engineer"
    },
    "question_generation_data": {
      "criterias": [
        
        {
          "skill": "Designing Distributed Systems",
          "criteria": "Advanced Infrastructure and Distributed Systems Development",
          "description": "Designing Distributed Systems involves the creation and management of multiple small systems that communicate and coordinate to perform a task. These systems are spread across different networks, and can be located globally. The design process takes into account factors such as network latency, data consistency, and fault tolerance.",
          "skimilar_skills": {
            "Design Coordination": 0.6379338326925692
          }
        },
        {
          "skill": "gRPC",
          "criteria": "Advanced Infrastructure and Distributed Systems Development",
          "description": "gRPC is a high-performance, open-source universal remote procedure call (RPC) framework. It allows a client application to directly call methods on a server application on a different machine as if it was a local object, making it easier for you to create distributed applications and services.",
          "skimilar_skills": {
            "GCP": 0.5367286554931886
          }
        },
        {
          "skill": "Protobuf",
          "criteria": "Advanced Infrastructure and Distributed Systems Development",
          "description": "Protobuf, or Protocol Buffers, is a binary protocol developed by Google. It is a highly efficient and compact format that serializes structured data, used in both internal applications and in APIs. It's language-neutral, platform-neutral, extensible mechanism for serializing structured data.",
          "skimilar_skills": {
            "dataproc": 0.576257442338379
          }
        },
        {
          "skill": "Kubernetes",
          "criteria": "Advanced Infrastructure and Distributed Systems Development",
          "description": "Kubernetes is an open-source platform designed to automate deploying, scaling, and operating application containers. It groups containers that make up an application into logical units for easy management and discovery.",
          "skimilar_skills": {
            "Hibernate": 0.6065841313238577
          }
        },
        {
          "skill": "AWS",
          "criteria": "Cloud Computing and Platform Services",
          "description": "AWS, or Amazon Web Services, is a comprehensive, evolving cloud computing platform provided by Amazon. It provides a mix of infrastructure as a service (IaaS), platform as a service (PaaS) and packaged software as a service (SaaS) offerings. AWS services can offer an organization tools such as compute power, database storage and content delivery services.",
          "skimilar_skills": {
            "AWS Security Stack": 0.7380173674754926
          }
        },
        {
          "skill": "Lucene",
          "criteria": "Big Data and Cloud-Based Storage Technologies",
          "description": "Lucene is a high-performance, full-featured text search engine library written entirely in Java. It is a technology suitable for nearly any application that requires full-text search, especially cross-platform. Lucene comes with powerful, flexible, and highly efficient functionalities to perform searching and indexing across many websites, books, and documents.",
          "skimilar_skills": {
            "HTML": 0.5632171170300169
          }
        },
        {
          "skill": "OAuth2",
          "criteria": "Network and Security Management Skills",
          "description": "OAuth2 is an authorization framework that enables applications to obtain limited access to user accounts on an HTTP service. It works by delegating user authentication to the service that hosts the user account and authorizing third-party applications to access the user account. OAuth2 provides a process for end-users to authorize third-party access to their server resources without sharing their credentials.",
          "skimilar_skills": {
            "AWS Security Stack": 0.4884492753055951
          }
        },
        {
          "skill": "Cryptography",
          "criteria": "Advanced Taxation and Confidential Data Management Skills",
          "description": "Cryptography involves creating written or generated codes that allow information to be kept secret. In digital security, cryptography provides the basis for several tools and techniques used to secure data and information systems. It includes techniques such as encryption (converting readable data into unreadable data to prevent unauthorized access) and decryption (converting the unreadable data back to its original form).",
          "skimilar_skills": {
            "Security": 0.6040771828041439
          }
        }
      ],
      "description": "No description",
      "position": "Software engineer"
    }
  }

# %%
#job parser output -> list of criteria and skill

import json
criteria_skill_dictionary = {}
for i in job_parser['question_selection_data']['criterias']:
    if i['criteria'] in criteria_skill_dictionary:
        criteria_skill_dictionary[i['criteria']].append(i['skill'])
    else:
        criteria_skill_dictionary[i['criteria']] =  [i['skill']]

print(json.dumps(criteria_skill_dictionary,indent =3))
# Out:
# {
#    "Web Development & Programming Skills": [
#       "Java"
#    ],
#    "Advanced Infrastructure and Distributed Systems Development": [
#       "Designing Distributed Systems",
#       "gRPC",
#       "Protobuf",
#       "Docker",
#       "Kubernetes"
#    ],
#    "Computer Science, Programming and Automation Skills": [
#       "UNIX/Linux"
#    ],
#    "Cloud Computing and Platform Services": [
#       "AWS"
#    ],
#    "Big Data and Cloud-Based Storage Technologies": [
#       "Lucene",
#       "kafka"
#    ],
#    "Network and Security Management Skills": [
#       "OAuth2"
#    ],
#    "Advanced Taxation and Confidential Data Management Skills": [
#       "Cryptography"
#    ],
#    "AI, Machine Learning and Deep Learning Skills": [
#       "machine learning",
#       "Deep Neural Networks"
#    ],
#    "Personal Development Skills": [
#       "Problem Solving",
#       "Self-Starter"
#    ],
#    "Communication, Ethics, and Team Collaboration": [
# ...

# %%
#initializing questions to all the skills -> default = 0

criteria_wise_questions = {}
for i in criteria_skill_dictionary:
    criteria_wise_questions[i] = 0

print(criteria_wise_questions)

total_number_of_questions = 35
initializer = 1

categories = sorted(criteria_wise_questions.keys(), key=lambda k: criteria_wise_questions[k], reverse=True)
print(categories)
while initializer <= total_number_of_questions:
    for key in categories:
        criteria_wise_questions[key] += 1
        initializer += 1
        if initializer > total_number_of_questions:
            break

print(criteria_wise_questions)
# Out:
# {'Web Development & Programming Skills': 0, 'Advanced Infrastructure and Distributed Systems Development': 0, 'Computer Science, Programming and Automation Skills': 0, 'Cloud Computing and Platform Services': 0, 'Big Data and Cloud-Based Storage Technologies': 0, 'Network and Security Management Skills': 0, 'Advanced Taxation and Confidential Data Management Skills': 0, 'AI, Machine Learning and Deep Learning Skills': 0, 'Personal Development Skills': 0, 'Communication, Ethics, and Team Collaboration': 0}
# ['Web Development & Programming Skills', 'Advanced Infrastructure and Distributed Systems Development', 'Computer Science, Programming and Automation Skills', 'Cloud Computing and Platform Services', 'Big Data and Cloud-Based Storage Technologies', 'Network and Security Management Skills', 'Advanced Taxation and Confidential Data Management Skills', 'AI, Machine Learning and Deep Learning Skills', 'Personal Development Skills', 'Communication, Ethics, and Team Collaboration']
# ...

# %%
#Main allocating question skill wise -> based on must have skills and known skills to the candidate  -->  If you want to change weightage the modify 

must_have_skills = ["Interpersonal Communication", "Java", "Designing Distributed Systems" ,"Kubernetes", "UNIX/Linux", "kafka"]
final_output = {}
print(criteria_wise_questions)
for i in criteria_wise_questions:
    Number_of_questions_criteria_wise = criteria_wise_questions[i]
    skills = criteria_skill_dictionary[i]
    must_have_skills_0 = []
    other_skills = []

    #dividing skills into 2 categories -> must have and others

    for i in skills:
        if i in must_have_skills:
            must_have_skills_0.append(i)
        else:
            other_skills.append(i)

    #dividing other skills into 2 categories -> candidate knows and don't knows

    other_high_priority = []
    other_low_priority = []
    

    for j in other_skills:
        if j in known_skills_to_candidate:
            other_high_priority.append(j)
        else:
            other_low_priority.append(j)
    

    print(must_have_skills_0)
    print(other_high_priority)
    print(other_low_priority)
    print('********')
    
    #various conditions that we need to tackle -> to allocate questions
    if (len(must_have_skills_0) != 0) and (len(other_high_priority) != 0) and (len(other_low_priority) != 0):
        
        must_have_percentage = 0.6
        other_high_priority_percentage = 0.25
        other_low_priority_percentage = 0.15

       
        num_of_question_must_have_skills = max(0, round(Number_of_questions_criteria_wise * must_have_percentage))
        num_of_question_other_high_priority_skills = max(0, round(Number_of_questions_criteria_wise * other_high_priority_percentage))
        num_of_question_other_low_priority_skills = Number_of_questions_criteria_wise - num_of_question_must_have_skills - num_of_question_other_high_priority_skills
        print(num_of_question_must_have_skills)
        print(num_of_question_other_high_priority_skills)
        print(num_of_question_other_low_priority_skills)
        if num_of_question_must_have_skills != 0:
            n = 0
            while n < num_of_question_must_have_skills:
                for i in must_have_skills_0:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_must_have_skills:
                        break

        if num_of_question_other_high_priority_skills != 0:
            n = 0
            while n < num_of_question_other_high_priority_skills:
                for i in other_high_priority:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_other_high_priority_skills:
                        break

        if num_of_question_other_low_priority_skills != 0 :
            n = 0
            while n < num_of_question_other_low_priority_skills:
                for i in other_low_priority:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_other_low_priority_skills:
                        break


    elif (len(must_have_skills_0) != 0) and (len(other_high_priority) != 0) and (len(other_low_priority) == 0):
        
        must_have_percentage = 0.7
        other_high_priority_percentage = 0.3

        num_of_question_must_have_skills = max(1, round(Number_of_questions_criteria_wise * must_have_percentage))
        num_of_question_other_high_priority_skills = max(0, Number_of_questions_criteria_wise - num_of_question_must_have_skills)

        if num_of_question_must_have_skills != 0:
            n = 0
            while n < num_of_question_must_have_skills:
                for i in must_have_skills_0:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_must_have_skills:
                        break

        if num_of_question_other_high_priority_skills != 0:
            n = 0
            while n < num_of_question_other_high_priority_skills:
                for i in other_high_priority:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_other_high_priority_skills:
                        break
    
    elif (len(must_have_skills_0) != 0) and (len(other_high_priority) == 0) and (len(other_low_priority) != 0):
        
        must_have_percentage = 0.7
        other_low_priority_percentage = 0.3

        num_of_question_must_have_skills = max(1, round(Number_of_questions_criteria_wise * must_have_percentage))
        num_of_question_other_low_priority_skills = max(0, Number_of_questions_criteria_wise - num_of_question_must_have_skills)

        if num_of_question_must_have_skills != 0:
            n = 0
            while n < num_of_question_must_have_skills:
                for i in must_have_skills_0:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_must_have_skills:
                        break

        if num_of_question_other_low_priority_skills != 0:
            n = 0
            while n < num_of_question_other_low_priority_skills:
                for i in other_low_priority:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_other_low_priority_skills:
                        break

    elif (len(must_have_skills_0) == 0) and (len(other_high_priority) != 0) and (len(other_low_priority) != 0):

        other_high_priority_percentage = 0.5
        other_low_priority_percentage = 0.5

        num_of_question_other_high_priority_skills = max(1, round(Number_of_questions_criteria_wise * other_high_priority_percentage))
        num_of_question_other_low_priority_skills = max(0, Number_of_questions_criteria_wise - num_of_question_must_have_skills)

        if num_of_question_other_high_priority_skills != 0:
            n = 0
            while n < other_high_priority_percentage:
                for i in other_high_priority:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= other_high_priority_percentage:
                        break

        if num_of_question_other_low_priority_skills != 0:
            n = 0
            while n < num_of_question_other_low_priority_skills:
                for i in other_low_priority:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_other_low_priority_skills:
                        break

    elif (len(must_have_skills_0) != 0) and (len(other_high_priority) == 0) and (len(other_low_priority) == 0):

        num_of_question_must_have_skills = Number_of_questions_criteria_wise

        if num_of_question_must_have_skills != 0:
            n = 0
            while n < num_of_question_must_have_skills:
                for i in must_have_skills_0:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_must_have_skills:
                        break

    elif (len(must_have_skills_0) == 0) and (len(other_high_priority) != 0) and (len(other_low_priority) == 0):

        num_of_question_other_high_priority_skills = Number_of_questions_criteria_wise

        if num_of_question_other_high_priority_skills != 0:
            n = 0
            while n < num_of_question_other_high_priority_skills:
                for i in other_high_priority:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_other_high_priority_skills:
                        break

    elif (len(must_have_skills_0) == 0) and (len(other_high_priority) == 0) and (len(other_low_priority) != 0):

        num_of_question_other_low_priority_skills = Number_of_questions_criteria_wise

        if num_of_question_other_low_priority_skills != 0:
            n = 0
            while n < num_of_question_other_low_priority_skills:
                for i in other_low_priority:
                    if i not in final_output:
                        final_output[i] = 1
                    else:
                        final_output[i] += 1
                    n += 1
                    if n >= num_of_question_other_low_priority_skills:
                        break

    print(final_output)
# Out:
# {'Web Development & Programming Skills': 4, 'Advanced Infrastructure and Distributed Systems Development': 4, 'Computer Science, Programming and Automation Skills': 4, 'Cloud Computing and Platform Services': 4, 'Big Data and Cloud-Based Storage Technologies': 4, 'Network and Security Management Skills': 3, 'Advanced Taxation and Confidential Data Management Skills': 3, 'AI, Machine Learning and Deep Learning Skills': 3, 'Personal Development Skills': 3, 'Communication, Ethics, and Team Collaboration': 3}
# ['Java']
# []
# []
# ********
# {'Java': 4}
# ['Designing Distributed Systems', 'Kubernetes']
# ['Protobuf', 'Docker']
# ['gRPC']
# ********
# 2
# 1
# 1
# {'Java': 4, 'Designing Distributed Systems': 1, 'Kubernetes': 1, 'Protobuf': 1, 'gRPC': 1}
# ['UNIX/Linux']
# []
# []
# ********
# {'Java': 4, 'Designing Distributed Systems': 1, 'Kubernetes': 1, 'Protobuf': 1, 'gRPC': 1, 'UNIX/Linux': 4}
# []
# ['AWS']
# []
# ********
# ...
